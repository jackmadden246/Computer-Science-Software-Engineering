# %% [markdown]
# Data science project

# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv("C:/Users/JackMadden/Downloads/Bank Loan Predictor/train.csv")

# %%
train_data.shape
# Out:
# (67463, 35)

# %%
pd.set_option('display.max_columns', None)

# %%
train_data.head(20)
# Out:
#           ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0   65087372        10000          32236            12329.362860    59
# 1    1450153         3609          11940            12191.996920    59
# 2    1969101        28276           9311            21603.224550    59
# 3    6651430        11170           6954            17877.155850    59
# 4   14354669        16890          13226            13539.926670    59
# 5   50509046        34631          30203             8635.931613    36
# 6   32737431        30844          19773            15777.511830    59
# 7   63151650        20744          10609             7645.014802    58
# 8    4279662         9299          11238            13429.456610    59
# 9    4431034        19232           8962             7004.097481    58
# 10  22010590         8640           6428             8169.779401    59
# 11   3975562        16581           8767            10637.049030    59
# ...

# %%
train_data.columns
# Out:
# Index(['ID', 'Loan Amount', 'Funded Amount', 'Funded Amount Investor', 'Term',
#        'Batch Enrolled', 'Interest Rate', 'Grade', 'Sub Grade',
#        'Employment Duration', 'Home Ownership', 'Verification Status',
#        'Payment Plan', 'Loan Title', 'Debit to Income',
#        'Delinquency - two years', 'Inquires - six months', 'Open Account',
#        'Public Record', 'Revolving Balance', 'Revolving Utilities',
#        'Total Accounts', 'Initial List Status', 'Total Received Interest',
#        'Total Received Late Fee', 'Recoveries', 'Collection Recovery Fee',
#        'Collection 12 months Medical', 'Application Type', 'Last week Pay',
#        'Accounts Delinquent', 'Total Collection Amount',
#        'Total Current Balance', 'Total Revolving Credit Limit', 'Loan Status'],
#       dtype='object')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67463 entries, 0 to 67462
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            67463 non-null  int64
#  1   Loan Amount                   67463 non-null  int64
#  2   Funded Amount                 67463 non-null  int64
#  3   Funded Amount Investor        67463 non-null  float64
#  4   Term                          67463 non-null  int64
#  5   Batch Enrolled                67463 non-null  object
#  6   Interest Rate                 67463 non-null  float64
#  7   Grade                         67463 non-null  object
#  8   Sub Grade                     67463 non-null  object
#  9   Employment Duration           67463 non-null  object
#  10  Home Ownership                67463 non-null  float64
#  11  Verification Status           67463 non-null  object
# ...

# %%
print(train_data.isnull().sum())
# Out:
# ID                              0
# Loan Amount                     0
# Funded Amount                   0
# Funded Amount Investor          0
# Term                            0
# Batch Enrolled                  0
# Interest Rate                   0
# Grade                           0
# Sub Grade                       0
# Employment Duration             0
# Home Ownership                  0
# Verification Status             0
# Payment Plan                    0
# Loan Title                      0
# Debit to Income                 0
# Delinquency - two years         0
# Inquires - six months           0
# Open Account                    0
# Public Record                   0
# Revolving Balance               0
# Revolving Utilities             0
# Total Accounts                  0
# Initial List Status             0
# Total Received Interest         0
# Total Received Late Fee         0
# Recoveries                      0
# Collection Recovery Fee         0
# ...

# %%
train_data['Loan Amount'].value_counts()
# Out:
# 15932    13
# 14424    12
# 15800    11
# 15639    11
# 15118    11
#          ..
# 2588      1
# 33968     1
# 5420      1
# 12285     1
# 8323      1
# Name: Loan Amount, Length: 27525, dtype: int64

# %%
#train_data.iloc[4:]

# %%
def find_column_type(train):
    all_cols = list(train.columns)
    numerical_cols_temp = train._get_numeric_data().columns
    categorical_cols = list(set(all_cols) - set(numerical_cols_temp))
    bool_cols = [col for col in all_cols if np.isin(df[col].dropna().unique(),[0,1,0.0,1.0]).all()]
    numerical_cols = list(set(numerical_cols_temp) - set(bool_cols))



    return categorical_cols,bool_cols,numerical_cols

# %%
print(train_data.loc[ train_data['Loan Amount'] <= 5000])
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 1       1450153         3609          11940             12191.99692    59
# 33     48337307         3406          12829             11484.27452    59
# 43      1853549         4710          24672             32097.00319    59
# 45     64288414         4130          13923             14998.47450    58
# 49      9747171         4959           8318             23011.48459    59
# ...         ...          ...            ...                     ...   ...
# 67378   7485714         3276          16491             13518.88679    59
# 67396   9020866         4391          12736             10556.28252    59
# 67424  38409649         2216          12384             14386.22283    36
# 67438  64968645         3443          31515             30719.69248    58
# 67443  54859438         1436           7927             11298.54377    59
#
#       Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  \
# ...

# %%
train_data
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0      65087372        10000          32236             12329.36286    59
# 1       1450153         3609          11940             12191.99692    59
# 2       1969101        28276           9311             21603.22455    59
# 3       6651430        11170           6954             17877.15585    59
# 4      14354669        16890          13226             13539.92667    59
# ...         ...          ...            ...                     ...   ...
# 67458  16164945        13601           6848             13175.28583    59
# 67459  35182714         8323          11046             15637.46301    59
# 67460  16435904        15897          32921             12329.45775    59
# 67461   5300325        16567           4975             21353.68465    59
# 67462  65443173        15353          29875             14207.44860    59
#
#       Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  \
# ...

# %%
train_data.loc[ train_data['Loan Amount'] <= 5000]
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 1       1450153         3609          11940             12191.99692    59
# 33     48337307         3406          12829             11484.27452    59
# 43      1853549         4710          24672             32097.00319    59
# 45     64288414         4130          13923             14998.47450    58
# 49      9747171         4959           8318             23011.48459    59
# ...         ...          ...            ...                     ...   ...
# 67378   7485714         3276          16491             13518.88679    59
# 67396   9020866         4391          12736             10556.28252    59
# 67424  38409649         2216          12384             14386.22283    36
# 67438  64968645         3443          31515             30719.69248    58
# 67443  54859438         1436           7927             11298.54377    59
#
#       Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  \
# ...

# %%
train_data.loc[(train_data['Loan Amount'] > 100) & (train_data['Term'] >= 20)]
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0      65087372        10000          32236             12329.36286    59
# 1       1450153         3609          11940             12191.99692    59
# 2       1969101        28276           9311             21603.22455    59
# 3       6651430        11170           6954             17877.15585    59
# 4      14354669        16890          13226             13539.92667    59
# ...         ...          ...            ...                     ...   ...
# 67458  16164945        13601           6848             13175.28583    59
# 67459  35182714         8323          11046             15637.46301    59
# 67460  16435904        15897          32921             12329.45775    59
# 67461   5300325        16567           4975             21353.68465    59
# 67462  65443173        15353          29875             14207.44860    59
#
#       Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  \
# ...
